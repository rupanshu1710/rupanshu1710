# %% [markdown]
# <a href="https://colab.research.google.com/github/rupanshu1710/rupanshu1710/blob/main/Chat_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# used a dictionary to represent an intents JSON file
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you?", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
print(words)
# Out:
# ["'s", 'adios', 'are', 'birthday', 'born', 'bye', 'called', 'cya', 'do', 'doing', 'for', 'g2g', 'hang', 'hello', 'hi', 'how', 'is', 'name', 'old', 'out', 'plan', 'see', 'some', 'there', 'this', 'time', 'to', 'up', 'wa', 'want', 'week', 'weekend', 'what', 'whats', 'when', 'who', 'ya', 'you', 'your']

# %%
print(classes)
# Out:
# ['age', 'date', 'goodbye', 'greeting', 'name']

# %%
print(doc_y)
# Out:
# ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'age', 'age', 'age', 'date', 'date', 'date', 'name', 'name', 'name', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye']

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 2000
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               5120
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 937ms/step - loss: 1.6661 - accuracy: 0.2105
# Epoch 2/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5888 - accuracy: 0.3158
# Epoch 3/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5274 - accuracy: 0.4211
# Epoch 4/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3933 - accuracy: 0.4737
# Epoch 5/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2212 - accuracy: 0.8421
# Epoch 6/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1818 - accuracy: 0.8421
# Epoch 7/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0181 - accuracy: 0.7368
# Epoch 8/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8916 - accuracy: 0.8947
# Epoch 9/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7246 - accuracy: 0.8421
# Epoch 10/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6537 - accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5828 - accuracy: 0.9474
# Epoch 12/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4305 - accuracy: 0.9474
# Epoch 13/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3374 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2992 - accuracy: 0.9474
# Epoch 15/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2182 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2903 - accuracy: 0.9474
# Epoch 17/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2243 - accuracy: 0.8947
# Epoch 18/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2439 - accuracy: 0.8947
# Epoch 19/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0746 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2327 - accuracy: 0.9474
# Epoch 21/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0819 - accuracy: 0.9474
# Epoch 22/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1209 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1037 - accuracy: 0.9474
# Epoch 25/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1828 - accuracy: 0.9474
# Epoch 26/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0984 - accuracy: 0.9474
# Epoch 27/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1070 - accuracy: 0.9474
# Epoch 28/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 0.9474
# Epoch 34/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9474
# Epoch 43/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1487 - accuracy: 0.9474
# Epoch 44/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0478 - accuracy: 0.9474
# Epoch 47/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.8683e-04 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0200e-04 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.5754e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.9641e-04 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.9353e-04 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.3280e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.6719e-04 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4941e-04 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1848e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4183e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6571e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9283e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0075e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.8749e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.6979e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4159e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5912e-04 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.1591e-05 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6066e-04 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6185e-04 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6035e-04 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4907e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.3441e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.4808e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9469e-04 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4066e-04 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 19ms/step - loss: 5.0948e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 37ms/step - loss: 2.7091e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.8057e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.4899e-04 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 5ms/step - loss: 5.8466e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 5ms/step - loss: 9.6656e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5645e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2936e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 6ms/step - loss: 5.2155e-05 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.5937e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2759e-05 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2264e-04 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7485e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 21ms/step - loss: 2.3232e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1121e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7836e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7729e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.4141e-05 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4632e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4953e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7830e-04 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 6ms/step - loss: 7.1736e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9299e-05 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5113e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.9838e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5616e-04 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3341e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.6754e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.3555e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4870e-06 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2817e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3882e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 18ms/step - loss: 7.6064e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 29ms/step - loss: 1.7315e-05 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9209e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5220e-05 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.2225e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 17ms/step - loss: 1.9877e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 18ms/step - loss: 2.1585e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1508e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2915e-04 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4637e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3504e-06 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0575e-05 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1464 - accuracy: 0.9474
# Epoch 181/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0567e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0518e-05 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2414e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1515e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1620e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1123e-04 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 52ms/step - loss: 1.9563e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.9578e-05 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0854e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8512e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0565e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2744e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3157e-04 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9474
# Epoch 197/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9904e-04 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5291e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0530e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %%
# running the chatbot
while True:
    message = input("")
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# what is your name?
# Kippi
